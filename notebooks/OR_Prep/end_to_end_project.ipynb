# %% [markdown]
# # End-to-End OR Project — Real Dataset
# **Plan:** 5-Month OR Analyst | Foundation Sprint Deliverable
# **Goal:** Full pipeline — load real data, clean, analyze, visualize, extract OR insight
#
# Suggested datasets: supply chain costs, demand forecasting, scheduling, vehicle routing
#
# Pipeline: Load → Explore → Clean → Analyze → Visualize → OR Insight

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load Data

# %%
# df = pd.read_csv('...')

# %% [markdown]
# ## 2. Explore

# %%
# df.shape, df.dtypes, df.describe(), df.head()

# %% [markdown]
# ## 3. Clean

# %%
# Handle missing values, fix dtypes

# %% [markdown]
# ## 4. Analyze

# %%
# groupby, aggregations, correlations

# %% [markdown]
# ## 5. Visualize

# %%
# Plots: histogram, bar chart, line chart

# %% [markdown]
# ## 6. OR Insight — Problem Formulation

# %% [markdown]
# Write the optimization problem here in plain text, then formalize it.

# %%
# Attempt a basic model setup
