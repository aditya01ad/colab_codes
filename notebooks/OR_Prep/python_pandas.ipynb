# %% [markdown]
# # Pandas — OR Analyst Prep
# **Plan:** 5-Month OR Analyst | Foundation Sprint | Week 1–2
# **Goal:** DataFrames for data manipulation and OR analysis
#
# Topics: Series, DataFrame, read_csv, loc/iloc, groupby, merge, missing data, OR demand tables

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series & DataFrame Creation

# %%
# pd.Series, pd.DataFrame

# %% [markdown]
# ## Reading Data

# %%
# pd.read_csv, pd.read_excel

# %% [markdown]
# ## Selection & Filtering

# %%
# loc, iloc, boolean filtering

# %% [markdown]
# ## GroupBy & Aggregations

# %%
# groupby, agg, pivot_table

# %% [markdown]
# ## Missing Data

# %%
# isna, dropna, fillna

# %% [markdown]
# ## OR Practice — Demand Table

# %%
# Build a demand/supply DataFrame, filter and aggregate
