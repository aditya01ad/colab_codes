# %% [markdown]
# # LeetCode Daily Log — OR Analyst Prep
# **Goal:** 3 Easy problems/day — arrays, strings, basic math
#
# Format per problem:
# - Problem name + link
# - Approach (1–2 lines)
# - Code
# - Time complexity

# %% [markdown]
# ---
# ## Week 1

# %% [markdown]
# ### Day 1 — DATE: ___

# %%
# Problem 1:
# Link:
# Approach:

# %%
# Problem 2:
# Link:
# Approach:

# %%
# Problem 3:
# Link:
# Approach:
